# %%
** void main() {
  String a ="Murat";
    print(a);
  int b = 5;
  print(b);
  bool c = true;
    if(c){
      print("Selam");
    }
    
    
  var a = 50;
  var b ="Selam";
  print("Sayı $a   Yazı: $b");
}


** void main() {
  String a ="thrthtreg";
    print(a.length);
   print(a.toUpperCase());
  double b = 5.34;
  print(b.round());
  b +=1;
  print(b);
    
  String t = "Murat";
  print("Benim Adım $t");  ## önemli
    print("benim adım ${t.toUpperCase()}");
     print("3 ile 5 in toplamı ${3+5}");
}

** void main() {
  List a =["w","erv","ergbd","wre",34,756,345,35,634,5,2];
  print(a);
  List<int> b =[42,6,7,4,3,2,35,4563,23];
  print(b[1]);  ##python mantığı
  List y =["Ben","Murat","degkd"];
  print(y[1][2]);
  print(y.length); ## uzunluğu yazar = 3
  y.add("Fenerbahçe");
  print(y);
  y.removeAt(1);
  y[2]= "Selam"; ## değiştirir
  print(y);

  

}

** void main() {
  Map sinav ={"murat":100 , "ali":90, "ahmet":69};
  print(sinav);
  sinav["ayşe"] = 60;
  print(sinav);
  sinav.remove("ali");
  print(sinav);
  

}

**void main() {
  bool a= true;
  int hiz = 70; 
  String durum ;
  
  if(a){
    print("Doğru");
  } 
  else if(!a){
    print("Yanlış");
  
  }
  if(1<5 && 4<3){
    print("Küçük");
  }
  else
    print("Selam");
    
  durum = hiz >60 ? "Sınır Aşıldı" : "Devam";   ## yada böyle yazabilirsin
  print(durum);
  
}

**void main() {

  for(var i=0;i<3;i++){
    print("Döngü çalıştı");
  }
  List a = [1,2,3,"dv","gdfv","ergd"];
  for(var x=0;x<a.length;x++){
    print("$x . index =  ${a[x]}");
  
  }
}

**void main() {
  kanalac() {
    print("kanal açıldı");
  }

  kanaldegis(int numara) {
    print("$numara . kanal açıldı");
  }

  kanalac();
  kanaldegis(10);

  toplama(int x, int y) {
    print("sayıların toplamı = ${x + y}");
  }

  toplama(6, 8);
    
    
 int toplama(int x, int y) => x+y ;   ## kısa yoldan fonksiyon yazma
  
  print(toplama(5,7));
}


**void main() {

  print("TOPLAMLAR = ${toplama(5,7)}");  

  zor(8);
}

 toplama(int a,int b){
    return a+b;
  }

 zor(int x,[int y=5]){  
    
    print("ilk $x ikinci $y");
  }

    
    
**void main() {
  
  
 fonk(top){
   top(3,4);
 }
  
  fonk((x,y) => print(x+y));   ##fonksiyonu farklı şekilde yazma
}




** void main() {
  yaz(e) {
    print(e);
  }

  List a = [12, 34, 45, 6, 43, 2];

  a.forEach(yaz);
}




**void main() {
  

  List<int> a = [12, 34, 45, 6, 43, 2];

  var x = a.where((int sayi)=>sayi<20);
  print(x);
    
    YADA
    
** void main() {
 

  bool kontrol(int sayi) {
    if (sayi < 20) {
      return true;
    } else {
      return false;
    }
  }
  
   List<int> a = [12, 34, 45, 6, 43, 2];

  var x = a.where(kontrol).toList();
  print(x);
}
    
**void main() {
  donus(int sayi) {
    return sayi + 10;
  }

  List<int> a = [12, 34, 45, 6, 43, 2];

  var x = a.map(donus).toList();      ##dönüştürüp tekrar yazar
  print(x);
}
    
    
    NESNE TABANLI PROG
    
** void main() {
  var a1 = Top();
  print(a1.boyut);
  print(a1.renk);

  var a2 = Top();
  a2.boyut = 7;       ##yeni özelllik kazanıyor
  a2.renk = "Sarı";
  print(a2.renk);
  a2.selamla();
}

class Top {
  String renk = "Mavi";
  double boyut = 5;
  String sekil = "Düz";
  
  selamla(){
    print("ben top");
  }
}
    
** void main() {
  var x = Top("kırmızı", 8, "yuvarlak");
  print(x.boyut);
  print(x.sekil);
}

class Top {
  String renk;
  double boyut;
  String sekil;

  Top(String renk, double boyut, String sekil) {
    this.boyut = boyut;
    this.renk = renk;            ## this özgün özellik kazandırır
    this.sekil = sekil;
  }
}


    
** void main() {
  Top x = Top(renk: "Sarı", boyut: 5, sekil: "düz");    ## top sınıfına ait öz. alır
  print(x.boyut);
  print(x.sekil);
  print(x.renk);
}

class Top {
  String renk;
  double boyut;
  String sekil;

  Top({this.renk, this.boyut, this.sekil});    ## kısaltma şeklinde
}

    
    
**void main() {
  Top x = Top(renk: "Sarı", boyut: 5, sekil: "düz");
  print(x.boyut);
  print(x.sekil);
  print(x.renk);
  
  var a = Baskettop();        ******
  a.renk="Mor";                *****
  print(a.renk);
  print(a.sekil);
}

class Top {
  String renk;
  double boyut;
  String sekil;

  Top({this.renk, this.boyut, this.sekil});
}

class Baskettop extends Top{    ## top sınıfının özelliklerini aldı
  
}

    
  
    
**void main() {
 
  var x1 = araba(renk: "sarı", boyut : 5, sekil :"düz");
  print(x1.boyut);
  print(x1.sekil);
  x1.tanimla();
  
  var x2= Baskettop();
  x2.tanimla();
}

class araba {
  String renk ;
  double boyut;
  String sekil ;
  
  araba({this.renk, this.boyut, this.sekil});
  
  tanimla(){
    print("ben araba");
  }

}
  class Baskettop extends araba{   
  
    tanimla(){
        super.tanimla();   ## bunu kullanırsan arabanın metodunu da çağırır
    print("ben top");      ##öncelik kendi metodunda
  }
  
}
    
    
** void main() {
 
  var x1 = pizza(renk: "sarı", boyut : 5, sekil :"düz");
  print(x1.boyut);
  print(x1.sekil);
  final x2 = pizza.standart();     ## direk özellikler geldi
  print(x2.boyut);    
 
}

class pizza {
  String renk ;
  double boyut;
  String sekil ;
  
  pizza({this.renk, this.boyut, this.sekil});
  
  pizza.standart(){      ## yeni bir pizza oluşturup özellikleri atadık
  renk="mor";
  boyut= 876;
  sekil="kare";
}

}
    
    
** void main() {
 
  var x1 = kare(8);
  print(x1.alan);
  print(x1.cevre);
}

class kare {

  int alan,cevre;
  
  kare(int a){
    this.alan= a*a;
    this.cevre=4*a; 
  }
}
    
    
CLASS: Bir nesne oluşturursan bir daha oluşturmana gerek kalmaz. Mesela ev için duvar oluştur her duvarın rengi boyutu farklıdır
    
    
*******************************************************************************************************************************
    
import 'package:flutter/material.dart';

final Color darkBlue = Color.fromARGB(255, 18, 32, 47);

void main() {
  runApp(Container(
    color: Colors.red,    ##ana sayfa
    child: Center(child: Text(           ##çocuğu merkez, merkezi çocuğu text
      "MERHABA",
      textDirection: TextDirection.ltr,                       ##text özellikleri
      style: TextStyle(color: Colors.white, fontSize: 20.0),
    ),)
  ));
}

    
** Sabit Widget Durumsuz widgettir. Stateleess
    
    
** Widget build(BuildContext context) {
    return MaterialApp(
      title: 'Flutter Demo',
      theme: ThemeData(


        primarySwatch: Colors.yellow,

        visualDensity: VisualDensity.adaptivePlatformDensity,
      ),
      home: Scaffold(appBar: AppBar(),),    ## yukarıda gördüğün temel widget (bar)
                                             ##scaffold=inşaat iskelesi
    );
  }  
    
    
**  home: Scaffold(
        appBar: AppBar(),
        body: Center (child:Text("HERKESE SELAMLAR",style: TextStyle(color: Colors.purpleAccent,fontSize: 30.0),),)
      ),
    
    ## her sayfada bir scaffold olmalı
    
    
***     home: Scaffold(
        appBar: AppBar(),
        body: Center (child:yazi("Osman","Gültekin",25))      ## ana sayfaya 3 parametre yollandı
      ),
    );
  }
}

class yazi extends StatelessWidget {
  final String ad;
  final String soyad;                                     ##parametreleri tanımladık
  final int yas;  
 
  yazi(this.ad,this.soyad,this.yas);

  @override
  Widget build(BuildContext context) {
    return Text(
      "İsim = $ad \nSoyisim = $soyad \nYaş=  $yas"              ##parametreleri girince buraya tanımladı
    );
  }
}



**   home: Scaffold(
          appBar: AppBar(),
          body: Column(children: [      ##kolonlarla birden fazla çocuk
            yazi("Ahmet", "Mehmet", 40),
            yazi("Osman", "Gültekin", 65),         ##farklı kimlikler tanımladım
          ])),
    );
  }
}

class yazi extends StatelessWidget {
  final String ad;
  final String soyad;
  final int yas;

  yazi(this.ad, this.soyad, this.yas);

  @override
  Widget build(BuildContext context) {
    return Text("İsim = $ad \nSoyisim = $soyad \nYaş=  $yas \n");
  }
}


**Durumlu Widget = Etkileşim ile değişebilir (Trafik lambaları gibi)
 Durumsuz= Sabittir değiştiremezsin final ile tanımlanır
    
** birden fazla sayfa varsa her sayfa için bir scaffold yapmak lazım.Flutterda Her sayfa bir widgettir


**       home: Sayac(
        "Bardak",       
      ),
    );
  }
}

class Sayac extends StatefulWidget {
  final String isim;
  Sayac(this.isim);                              ##isimi sabit kalacak bu yüzden finalle tanımladık
  @override
  _SayacState createState() => _SayacState();
}

class _SayacState extends State<Sayac> {
  int sayi = 0;
  @override
  Widget build(BuildContext context) {
    return Scaffold(
      appBar: AppBar(),
      body: Center (child:(Text("${widget.isim} sayısı $sayi",style:TextStyle(color: Colors.purpleAccent,fontSize: 30.0)))),
      floatingActionButton: FloatingActionButton(onPressed: () {              ##bodye yazdırdık ve basılması için on press
        setState(() {          ##değişiklik olduğunda haberi olması için set içine aldık
          sayi++;
          print("sayı= $sayi");
        });
      }),
    );
  }
}




****** import 'package:flutter/material.dart';

void main() => runApp(MyApp());

class MyApp extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    return MaterialApp(
      debugShowCheckedModeBanner: false,
      title: 'Projem',
      theme: ThemeData(
        primarySwatch: Colors.purple,      ## ana rengi mor olarak belirledik
      ),
      home: GirisSayfasi(),
    );
  }
}

class GirisSayfasi extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    return Scaffold(
        backgroundColor: Theme.of(context).primaryColor,     ##arka plana ana rengi koyduk
        body: Center(             ## kolon ekledik ve ortada olması için merkeze koyduk
          child: Column(
            children: <Widget>[
              SizedBox(
                height: 55.0,        ##yukarıyla logo arasına boşluk koyduk (görünmez bir kutu)
              ),
              Container(
                width: 120.0,                  ##bir container açtık ve
                height: 120.0,
                decoration: BoxDecoration(          ##içine resim koyduk
                  image: DecorationImage(image: AssetImage("assets/robot-2192617_640.png"))
                ),
              ),
              SizedBox(
                height: 25.0,                    ##resimle yazı arasına yine boşluk için görünmez kutu koyduk
              ),
              Text("Sociaworld",
                  style: TextStyle(
                      color: Colors.white,             ##logonun altına yazı ekledık ve özellikler belirledik
                      fontSize: 30.0,
                      fontWeight: FontWeight.bold)),
              SizedBox(
                height: 35.0,                ## yine boşluk
              ),
              Material(
                borderRadius: BorderRadius.circular(20.0),    ##dış kısma eğim verdi
                elevation: 7.0,    ##sanki bir kat yukarıdaymış gibi
                child: Container(
                  child: Column(
                    mainAxisAlignment: MainAxisAlignment.center,     ##containerin içindekileri ortaya hizaladı
                    children: <Widget>[
                      Padding(
                        padding: const EdgeInsets.all(12.0),
                        child: Container(
                          alignment: Alignment.center,
                          child: Text(
                            "Mail İle Giriş",
                            style: TextStyle(
                                fontSize: 18.0,
                                fontWeight: FontWeight.bold,
                                color: Colors.white),
                          ),
                          width: double.infinity,
                          height: 52.0,
                          decoration: BoxDecoration(
                              color: Colors.purple,
                              borderRadius: BorderRadius.circular(20.0)),        
                        ),
                      ),
                      Padding(
                        padding: const EdgeInsets.all(12.0),
                        child: Row(    ##yan yana eklemeyi sağlar
                          children: <Widget>[
                            Expanded(
                              child: Container(
                                alignment: Alignment.center,
                                child: Text(
                                  "Facebook Giriş",
                                  style: TextStyle(
                                      fontSize: 18.0,
                                      fontWeight: FontWeight.bold,
                                      color: Colors.white),
                                ),
                                height: 52.0,
                                decoration: BoxDecoration(
                                    color: Colors.indigo,
                                    borderRadius: BorderRadius.circular(20.0)),
                              ),
                            ),
                            SizedBox(
                              width: 10.0,
                            ),
                            Expanded(              ##genişletme
                              child: Container(
                                alignment: Alignment.center,
                                child: Text(
                                  "Gmail Giriş",
                                  style: TextStyle(
                                      fontSize: 18.0,
                                      fontWeight: FontWeight.bold,
                                      color: Colors.white),
                                ),
                                height: 52.0,
                                decoration: BoxDecoration(
                                    color: Color.fromARGB(255, 227, 66, 100),
                                    borderRadius: BorderRadius.circular(20.0)),
                              ),
                            )
                          ],
                        ),
                      ),
                    ],
                  ),
                  decoration: BoxDecoration(
                      gradient: LinearGradient(           ##bir köşeden diğerine değişen renkler
                          begin: Alignment.topLeft,
                          end: Alignment.bottomRight,   ##nerden nereye değişecek
                          colors: [
                            Colors.purple[300],         ##renk koyuluğu
                            Colors.purple[100],
                          ]),
                      color: Colors.white,
                      borderRadius: BorderRadius.circular(20.0)),     ##kenarlık
                  alignment: Alignment.center,
                  width: MediaQuery.of(context).size.width - 70.0,      #genişliği sağdan solda 35 px kısar
                  height: 180.0,
                ),
              )
            ],
          ),
        ));
  }
}


NOTLAR:    width: MediaQuery.of(context).size.width-70,      ##telefon ekranının boyutundan 70 px eksik
                        alignment: Alignment(1,0.58),    ##hizalarken xve y eksenini alır -1 ve 1 arası altta y=1
                padding: yalancı doldurma (içten mesafe koyar)
                margin: dıştan sosyal mesafe koyar :)
                        
                   
                
                
**** column da alt alta sıralarken ekranı taşarsa olmaz o yüzden ListView kullanırsan kaydırma özelliği eklersin
**   IconButton(
            icon: Icon(
              Icons.notification_important,
              color: Colors.purple[200],               ##basılabilir ikon ekler
              size: 32.0,
            ),
            onPressed: (){},
          ),

***** ListView(
              scrollDirection: Axis.horizontal,    ##yana kaydırmalı olacaksa horizontal olacak
    
********  uzun bir kodu tekrar tekrar yazmak yerine ör: Column sağ tuş extrach method diyip metot oluştur ve metodu kopyala
    
**** internetten resim çekmek için :
 image: DecorationImage(image: NetworkImage("https://cdn.pixabay.com/photo/2021/01/22/14/24/cat-5940106_1280.jpg")),
    
    
**** Container stack içine alırsan üst üste koyar .Alttaki Containeri üste koyar.
      Stack(
            alignment: Alignment.topRight,    ##üsttekinin konumu
            children: <Widget>[
            Container(............
    
    
    
**** Padding(
            padding: const EdgeInsets.all(12.0),       #padding kısayol
            child: 

*** Text(
                    "isim soyisim",
                    style: TextStyle(                            ##text kısayol
                        color: Colors.green,
                        fontSize: 20.0,
                        fontWeight: FontWeight.bold),
                  ),
    
***   IconButton(
            icon: Icon(
              Icons.notification_important,
              color: Colors.purple[200],            ##basılabilir ikon kısayol
              size: 32.0,
            ),
            onPressed: () {},
          ),
    
    
    
****  Image.network("https://cdn.pixabay.com/photo/2016/09/28/08/28/art-1699977_1280.jpg",
              width: double.infinity, 
                height: 200.0,                       ##internetten düzenli resim çekme işi
                fit: BoxFit.cover,
              ),
** wrap with ... için alt + enter yap
    
** ınkwell sıçrama efekti verir basılınca
    
    Material(
      color: Colors.white,
      child: InkWell(        wrap widget yap widget sil ınwell yaz
                     
                
***   FlatButton.icon(onPressed: (){}, icon: Icon(Icons.share,color: Colors.purple[200],), 
                      label: Text("Paylaş",style: TextStyle(color:Colors.grey ),))    ##kısayoldan buton yazı yapma
                     
                     
                     
                
                     
** Material(
      child: InkWell(
        onTap: (){},      ##tıklanabilir özellik
          
          
*** InkWell(
        onTap: (){
          Navigator.push(context, Material (cupertino olsa sağdan efekt verir)   PageRoute(builder: (BuildContext context) {
            return profilsayfasi();              ##push metodu bir sayfanın üzerine başka sayfa ekler
                                                    ##yani yeni sayfa açmayı sağlar nereye gidecekse return a yaz
          }));
        },
    
** push ekler pop kaldırır
    return Scaffold(
      body: Center(childs: FlatButton(onPressed: (){Navigator.pop(context);}, child: Text("Geriye gel")),),
    );                   ##basınca geri gelir
    
    
    
**** Positioned(
                left: 20.0,             #bir yere konumlandırmak için positioned içine al
                bottom: 0.0,
                child: Container(
                    
                    
*** IconButton(icon: Icon(Icons.arrow_back, color: Colors.black,), onPressed:() {Navigator.pop(context);})   ##geri dönüş butonu
                    
                    
                    
                    
**** decoration: BoxDecoration(
                    image: DecorationImage(
                        image: NetworkImage(                       ##resim ekleme kısayolu
                            "https://cdn.pixabay.com/photo/2021/01/05/01/15/home-5889366_1280.jpg"),
                      fit: BoxFit.cover,

                    ),
                ),
